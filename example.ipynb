# %%
import torch

models = torch.hub.list("chenyaofo/pytorch-cifar-models", force_reload=True)
models
# Out:
# Downloading: "https://github.com/chenyaofo/pytorch-cifar-models/zipball/master" to /home/huj0b/.cache/torch/hub/master.zip
# ['cifar100_mobilenetv2_x0_5',
#  'cifar100_mobilenetv2_x0_75',
#  'cifar100_mobilenetv2_x1_0',
#  'cifar100_mobilenetv2_x1_4',
#  'cifar100_repvgg_a0',
#  'cifar100_repvgg_a1',
#  'cifar100_repvgg_a2',
#  'cifar100_resnet20',
#  'cifar100_resnet32',
#  'cifar100_resnet44',
#  'cifar100_resnet56',
#  'cifar100_shufflenetv2_x0_5',
#  'cifar100_shufflenetv2_x1_0',
#  'cifar100_shufflenetv2_x1_5',
#  'cifar100_shufflenetv2_x2_0',
#  'cifar100_vgg11_bn',
#  'cifar100_vgg13_bn',
#  'cifar100_vgg16_bn',
#  'cifar100_vgg19_bn',
#  'cifar100_vit_b16',
#  'cifar100_vit_b32',
#  'cifar100_vit_h14',
#  'cifar100_vit_l16',
#  'cifar100_vit_l32',
#  'cifar10_mobilenetv2_x0_5',
#  'cifar10_mobilenetv2_x0_75',
#  'cifar10_mobilenetv2_x1_0',
#  'cifar10_mobilenetv2_x1_4',
#  'cifar10_repvgg_a0',
#  'cifar10_repvgg_a1',
#  'cifar10_repvgg_a2',
#  'cifar10_resnet20',
# ...

# %%
# !python -m entry.run --conf conf/cifar10.conf -o output/cifar10/resnet20 -M model.name=cifar10_resnet20
# Out:
# /ibex/user/huj0b/project/image-classification-codebase/codebase/data/imagenet/dali.py:12: UserWarning: NVIDIA DALI library is unavailable, cannot load and preprocess dataset with DALI.
#   warnings.warn("NVIDIA DALI library is unavailable, cannot load and preprocess dataset with DALI.")
# 2025-02-06 11:51:15,616 INFO    : Set the training job to be reproducible with seed=25992 (more detailed can be found at https://pytorch.org/docs/stable/notes/randomness.html)
# 2025-02-06 11:51:24,555 INFO    : Collect envs from system:
# PyTorch version: 2.5.1+cu124
# Is debug build: False
# CUDA used to build PyTorch: 12.4
# ROCM used to build PyTorch: N/A
#
# OS: Rocky Linux release 9.4 (Blue Onyx) (x86_64)
# GCC version: (GCC) 11.4.1 20231218 (Red Hat 11.4.1-3)
# Clang version: Could not collect
# CMake version: version 3.26.5
# Libc version: glibc-2.34
#
# Python version: 3.10.15 (main, Oct  3 2024, 07:27:34) [GCC 11.2.0] (64-bit runtime)
# ...

# %%
# !python -m entry.run --conf conf/cifar10.conf -o output/cifar10/repvgg_a0 -M model.name=cifar10_repvgg_a0 model.pretrained=true only_evaluate=true
# Out:
# /ibex/user/huj0b/project/image-classification-codebase/codebase/data/imagenet/dali.py:12: UserWarning: NVIDIA DALI library is unavailable, cannot load and preprocess dataset with DALI.
#   warnings.warn("NVIDIA DALI library is unavailable, cannot load and preprocess dataset with DALI.")
# 2025-02-05 22:51:05,022 INFO    : ------------------------------Resume from the last training checkpoints.------------------------------
# 2025-02-05 22:51:05,025 INFO    : Set the training job to be reproducible with seed=31225 (more detailed can be found at https://pytorch.org/docs/stable/notes/randomness.html)
# 2025-02-05 22:51:13,380 INFO    : Collect envs from system:
# PyTorch version: 2.5.1+cu124
# Is debug build: False
# CUDA used to build PyTorch: 12.4
# ROCM used to build PyTorch: N/A
#
# OS: Rocky Linux release 9.4 (Blue Onyx) (x86_64)
# GCC version: (GCC) 11.4.1 20231218 (Red Hat 11.4.1-3)
# Clang version: Could not collect
# CMake version: version 3.26.5
# Libc version: glibc-2.34
#
# ...
